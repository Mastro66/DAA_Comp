# %% [markdown]
# # DAA - Competição

# %% [markdown]
# Grupo:
# - Catarina Costa pg52676
# - Fernado Alves pg54470
# - Marta Aguiar pg52694

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_energia1 = pd.read_csv('datasets/energia_202109-202112.csv', encoding='latin1')
df_energia2 = pd.read_csv('datasets/energia_202201-202212.csv', encoding='latin1')
# Temos que prever os valores da energia injetada no dataset abaixo
df_energia3 = pd.read_csv('datasets/energia_202301-202304.csv', encoding='latin1')
df_meteo1 = pd.read_csv('datasets/meteo_202109-202112.csv', encoding='latin1')
df_meteo2 = pd.read_csv('datasets/meteo_202201-202212.csv', encoding='latin1')
df_meteo3 = pd.read_csv('datasets/meteo_202301-202304.csv', encoding='latin1')
df_open = pd.read_csv('datasets/open-meteo-41.58N8.44W193m.csv', delimiter=',')
df_submission = pd.read_csv('datasets/dummy_submission.csv')

# %%
df_energia1
# Out:
#             Data  Hora  Normal (kWh)  Horário Económico (kWh)  \
# 0     2021-09-29     0         0.000                    0.000
# 1     2021-09-29     1         0.000                    0.000
# 2     2021-09-29     2         0.000                    0.000
# 3     2021-09-29     3         0.000                    0.000
# 4     2021-09-29     4         0.000                    0.000
# ...          ...   ...           ...                      ...
# 2251  2021-12-31    19         2.176                    0.000
# 2252  2021-12-31    20         0.732                    0.000
# 2253  2021-12-31    21         0.704                    0.000
# 2254  2021-12-31    22         0.000                    0.424
# 2255  2021-12-31    23         0.000                    0.432
#
#       Autoconsumo (kWh) Injeção na rede (kWh)
# 0                   0.0                   NaN
# 1                   0.0                   NaN
# 2                   0.0                   NaN
# ...

# %%
df_energia2
# Out:
#             Data  Hora  Normal (kWh)  Horário Económico (kWh)  \
# 0     2022-01-01     0         0.000                    0.486
# 1     2022-01-01     1         0.000                    0.429
# 2     2022-01-01     2         0.000                    0.463
# 3     2022-01-01     3         0.000                    0.545
# 4     2022-01-01     4         0.000                    0.439
# ...          ...   ...           ...                      ...
# 8755  2022-12-31    19         1.693                    0.000
# 8756  2022-12-31    20         1.327                    0.000
# 8757  2022-12-31    21         0.757                    0.000
# 8758  2022-12-31    22         0.000                    0.675
# 8759  2022-12-31    23         0.000                    0.403
#
#       Autoconsumo (kWh) Injeção na rede (kWh)
# 0                   0.0                   NaN
# 1                   0.0                   NaN
# 2                   0.0                   NaN
# ...

# %%
df_energia3['Injeção na rede (kWh)'] = np.nan
df_energia3
# Out:
#             Data  Hora  Normal (kWh)  Horário Económico (kWh)  \
# 0     2023-01-01     0         0.000                    0.467
# 1     2023-01-01     1         0.000                    0.577
# 2     2023-01-01     2         0.000                    0.346
# 3     2023-01-01     3         0.000                    0.270
# 4     2023-01-01     4         0.000                    0.252
# ...          ...   ...           ...                      ...
# 2251  2023-04-04    19         0.953                    0.000
# 2252  2023-04-04    20         0.915                    0.000
# 2253  2023-04-04    21         0.479                    0.000
# 2254  2023-04-04    22         0.000                    0.497
# 2255  2023-04-04    23         0.000                    0.487
#
#       Autoconsumo (kWh)  Injeção na rede (kWh)
# 0                 0.000                    NaN
# 1                 0.000                    NaN
# 2                 0.000                    NaN
# ...

# %%
df_meteo1 = df_meteo1.drop(['sea_level', 'grnd_level', 'city_name'], axis=1)
df_meteo1
# Out:
#               dt                         dt_iso   temp  feels_like  temp_min  \
# 0     1630454400  2021-09-01 00:00:00 +0000 UTC  18.74       18.84     15.72
# 1     1630458000  2021-09-01 01:00:00 +0000 UTC  18.73       18.83     15.72
# 2     1630461600  2021-09-01 02:00:00 +0000 UTC  17.84       17.98     16.72
# 3     1630465200  2021-09-01 03:00:00 +0000 UTC  18.27       18.40     16.68
# 4     1630468800  2021-09-01 04:00:00 +0000 UTC  17.81       17.97     16.12
# ...          ...                            ...    ...         ...       ...
# 2923  1640977200  2021-12-31 19:00:00 +0000 UTC  16.72       16.35     16.22
# 2924  1640980800  2021-12-31 20:00:00 +0000 UTC  16.54       16.10     15.67
# 2925  1640984400  2021-12-31 21:00:00 +0000 UTC  15.71       15.09     15.66
# 2926  1640988000  2021-12-31 22:00:00 +0000 UTC  16.59       15.98     16.21
# 2927  1640991600  2021-12-31 23:00:00 +0000 UTC  16.59       16.00     16.21
#
# ...

# %%
df_meteo2 = df_meteo2.drop(['sea_level', 'grnd_level', 'city_name'], axis=1)
df_meteo2
# Out:
#               dt                         dt_iso   temp  feels_like  temp_min  \
# 0     1640995200  2022-01-01 00:00:00 +0000 UTC  16.59       16.00     16.21
# 1     1640998800  2022-01-01 01:00:00 +0000 UTC  16.59       16.00     16.21
# 2     1641002400  2022-01-01 02:00:00 +0000 UTC  16.59       16.03     15.67
# 3     1641006000  2022-01-01 03:00:00 +0000 UTC  13.59       12.75     11.61
# 4     1641009600  2022-01-01 04:00:00 +0000 UTC  14.97       14.27     14.72
# ...          ...                            ...    ...         ...       ...
# 8755  1672513200  2022-12-31 19:00:00 +0000 UTC  15.70       15.57     15.57
# 8756  1672516800  2022-12-31 20:00:00 +0000 UTC  15.55       15.43     12.72
# 8757  1672520400  2022-12-31 21:00:00 +0000 UTC  13.45       13.28     12.23
# 8758  1672524000  2022-12-31 22:00:00 +0000 UTC  12.93       12.73     12.23
# 8759  1672527600  2022-12-31 23:00:00 +0000 UTC  12.93       12.76     12.23
#
# ...

# %%
df_meteo3 = df_meteo3.drop(['sea_level', 'grnd_level', 'city_name'], axis=1)
df_meteo3
# Out:
#               dt                         dt_iso   temp  feels_like  temp_min  \
# 0     1672531200  2023-01-01 00:00:00 +0000 UTC  12.93       12.76     12.72
# 1     1672534800  2023-01-01 01:00:00 +0000 UTC  13.49       13.38     13.43
# 2     1672538400  2023-01-01 02:00:00 +0000 UTC  13.55       13.44     13.48
# 3     1672542000  2023-01-01 03:00:00 +0000 UTC  13.61       13.51     12.01
# 4     1672545600  2023-01-01 04:00:00 +0000 UTC  13.59       13.49     12.01
# ...          ...                            ...    ...         ...       ...
# 1747  1678820400  2023-03-14 19:00:00 +0000 UTC  13.10       12.27     12.72
# 1748  1678824000  2023-03-14 20:00:00 +0000 UTC  12.30       11.83     10.72
# 1749  1678827600  2023-03-14 21:00:00 +0000 UTC  11.77       11.30     10.26
# 1750  1678831200  2023-03-14 22:00:00 +0000 UTC  10.68       10.13      9.15
# 1751  1678834800  2023-03-14 23:00:00 +0000 UTC  10.65       10.15      8.60
#
# ...

# %%
df_meteo3.nunique()
# Out:
# dt                     1752
# dt_iso                 1752
# temp                    889
# feels_like             1007
# temp_min                169
# temp_max                174
# pressure                 31
# humidity                 71
# wind_speed              512
# rain_1h                 120
# clouds_all               99
# weather_description       8
# dtype: int64

# %%
df_meteo3.nunique()
# Out:
# dt                     1752
# dt_iso                 1752
# temp                    889
# feels_like             1007
# temp_min                169
# temp_max                174
# pressure                 31
# humidity                 71
# wind_speed              512
# rain_1h                 120
# clouds_all               99
# weather_description       8
# dtype: int64

# %%
df_meteo3.nunique()
# Out:
# dt                     1752
# dt_iso                 1752
# temp                    889
# feels_like             1007
# temp_min                169
# temp_max                174
# pressure                 31
# humidity                 71
# wind_speed              512
# rain_1h                 120
# clouds_all               99
# weather_description       8
# dtype: int64

# %%
df_meteo1.rename(columns={'Data': 'date', 'Hora': 'hour'}, inplace=True)
df_meteo1
# Out:
#               dt                         dt_iso   temp  feels_like  temp_min  \
# 0     1630454400  2021-09-01 00:00:00 +0000 UTC  18.74       18.84     15.72
# 1     1630458000  2021-09-01 01:00:00 +0000 UTC  18.73       18.83     15.72
# 2     1630461600  2021-09-01 02:00:00 +0000 UTC  17.84       17.98     16.72
# 3     1630465200  2021-09-01 03:00:00 +0000 UTC  18.27       18.40     16.68
# 4     1630468800  2021-09-01 04:00:00 +0000 UTC  17.81       17.97     16.12
# ...          ...                            ...    ...         ...       ...
# 2923  1640977200  2021-12-31 19:00:00 +0000 UTC  16.72       16.35     16.22
# 2924  1640980800  2021-12-31 20:00:00 +0000 UTC  16.54       16.10     15.67
# 2925  1640984400  2021-12-31 21:00:00 +0000 UTC  15.71       15.09     15.66
# 2926  1640988000  2021-12-31 22:00:00 +0000 UTC  16.59       15.98     16.21
# 2927  1640991600  2021-12-31 23:00:00 +0000 UTC  16.59       16.00     16.21
#
# ...

# %%
df_energia1
# Out:
#             Data  Hora  Normal (kWh)  Horário Económico (kWh)  \
# 0     2021-09-29     0         0.000                    0.000
# 1     2021-09-29     1         0.000                    0.000
# 2     2021-09-29     2         0.000                    0.000
# 3     2021-09-29     3         0.000                    0.000
# 4     2021-09-29     4         0.000                    0.000
# ...          ...   ...           ...                      ...
# 2251  2021-12-31    19         2.176                    0.000
# 2252  2021-12-31    20         0.732                    0.000
# 2253  2021-12-31    21         0.704                    0.000
# 2254  2021-12-31    22         0.000                    0.424
# 2255  2021-12-31    23         0.000                    0.432
#
#       Autoconsumo (kWh) Injeção na rede (kWh)
# 0                   0.0                   NaN
# 1                   0.0                   NaN
# 2                   0.0                   NaN
# ...

# %%
# Converter a coluna 'dt_iso' para datetime
df_energia1['dt_iso'] = pd.to_datetime(df_energia1['dt_iso'], format='%Y-%m-%d %H:%M:%S %z UTC')

# Criar novas colunas 'date' e 'hour'
df_energia1['date'] = df_energia1['dt_iso'].dt.strftime('%Y-%m-%d')
df_energia1['hour'] = df_energia1['dt_iso'].dt.hour

# Reordenar as colunas
df_energia1 = df_energia1[['date', 'hour'] + [col for col in df_energia1.columns if col not in ['dt_iso', 'date', 'hour']]]

# Exibir o DataFrame resultante
df_energia1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dt_iso'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Converter a coluna 'dt_iso' para datetime
# ...
